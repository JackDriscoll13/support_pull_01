# %%
from sqlalchemy import create_engine 
import pandas as pd

# %%
# Establish connection 
mysql_engine = create_engine('mysql://root:Mako1234@localhost:3306/kosherdb')

# %%
# Start exploring tables I want
ticketdepartments = pd.read_sql_table('tblticketdepartments', mysql_engine)

# %%
ticketdepartments
# Out:
#    id              name                                        description  \
# 0   1           Support  For technical support regarding your server. C...
# 1   2          Accounts  For help with accounts issues (payments, invoi...
# 2   3   Sales / General  For sales questions and general inquiries. You...
# 3   5  Abuse Department                                              Abuse
# 4   7             Legal                                              Legal
#
#                   email clientsonly piperepliesonly noautoresponder hidden  \
# 0   support@ramnode.com          on
# 1  accounts@ramnode.com          on
# 2     sales@ramnode.com
# 3     abuse@ramnode.com                                          on     on
# 4     legal@ramnode.com                                          on     on
#
#    order           host port                    login  \
# 0      1  pop.gmail.com  995      support@ramnode.com
# 1      2  pop.gmail.com  995     accounts@ramnode.com
# ...

# %%
# This table takes a long time to read in 
tickets= pd.read_sql_table('tbltickets', mysql_engine)

# %%
tickets['replyingtime']
# Out:
# Index(['id', 'tid', 'did', 'userid', 'contactid', 'requestor_id', 'name',
#        'email', 'cc', 'c', 'ipaddress', 'date', 'title', 'message', 'status',
#        'urgency', 'admin', 'attachment', 'attachments_removed', 'lastreply',
#        'flag', 'clientunread', 'adminunread', 'replyingadmin', 'replyingtime',
#        'service', 'merged_ticket_id', 'editor', 'updated_at'],
#       dtype='object')

# %%
tickets['date']
# Out:
# 0        2012-06-12 03:40:33
# 1        2012-06-13 01:56:44
# 2        2012-06-13 03:10:03
# 3        2012-06-13 04:34:41
# 4        2012-06-13 10:42:55
#                  ...
# 227469   2022-09-20 08:43:26
# 227470   2022-09-20 09:16:16
# 227471   2022-09-20 09:42:17
# 227472   2022-09-20 09:21:19
# 227473   2022-09-20 09:50:09
# Name: date, Length: 227474, dtype: datetime64[ns]

# %%
tickets['replyingtime'][227473]
# Out:
# NaT

# %%
ticketreplies = pd.read_sql_table('tblticketreplies', mysql_engine)

# %%
ticketreplies['admin'].unique()
# Out:
# array(['Nick Adams', '', 'Tyler Salwierz', 'Chris Easton', 'Elliot Speck',
#        'Spencer Sword', 'Raoul Vos', 'Matt McGowan', 'Matt M.', 'Nick A.',
#        'Raoul V.', 'Spencer S.', 'Marc van Rooij', 'Gus N', 'Gus N.',
#        'Chris B.', 'George T.', 'Brandon W.', 'Sean S.', 'Sean P.',
#        'Mike A.', 'Scott L.', 'Caleb B.', 'RamNode Legal', 'Vanessa V.'],
#       dtype=object)

# %%
tickets.columns
# Looks like maybe did is department id
# Out:
# Index(['id', 'tid', 'did', 'userid', 'contactid', 'requestor_id', 'name',
#        'email', 'cc', 'c', 'ipaddress', 'date', 'title', 'message', 'status',
#        'urgency', 'admin', 'attachment', 'attachments_removed', 'lastreply',
#        'flag', 'clientunread', 'adminunread', 'replyingadmin', 'replyingtime',
#        'service', 'merged_ticket_id', 'editor', 'updated_at'],
#       dtype='object')

# %%
tickets.did.unique()
# Out:
# array([1, 3, 2, 5, 7], dtype=int64)

# %%
ticketstats= pd.read_sql_table('tblticketstatuses', mysql_engine)
tickets['tid'].unique()
# Out:
# array(['230889', '924025', '976293', ..., '653121', '342239', '794640'],
#       dtype=object)

# %%
len(tickets['tid'].unique())

# %%
tickets[tickets['tid'] == '976293'][['date','replyingtime']]
# Out:
#                  date replyingtime
# 2 2012-06-13 03:10:03          NaT

# %%
tickets[tickets['tid'] == '230224']
# Out:
# Empty DataFrame
# Columns: [id, tid, did, userid, contactid, requestor_id, name, email, cc, c, ipaddress, date, title, message, status, urgency, admin, attachment, attachments_removed, lastreply, flag, clientunread, adminunread, replyingadmin, replyingtime, service, merged_ticket_id, editor, updated_at]
# Index: []
#
# [0 rows x 29 columns]

# %%
tickets
# Out:
#             id     tid  did  userid  contactid  requestor_id         name  \
# 0            2  230889    1      14          0             0
# 1            3  924025    1       6          0             0
# 2            4  976293    1      13          0             0
# 3            5  234515    1      16          0             0
# 4            6  205616    1      17          0             0
# ...        ...     ...  ...     ...        ...           ...          ...
# 227469  230222  711561    1   94876          0         94698
# 227470  230223  489667    2   17294          0         13832
# 227471  230225  653121    1     590          0           614
# 227472  230224  342239    1   93235          0         93337
# 227473  230226  794640    3       0          0             0  Claire Ward
#
#                              email cc         c  ...           lastreply flag  \
# 0                                      Mjrwm6se  ... 2012-06-12 07:17:36    0
# ...

# %%
ticketreplies[ticketreplies['tid'] == 230224]
#ticketreplies[ticketreplies['tid'] == 227473]
# Out:
# Empty DataFrame
# Columns: [id, tid, userid, contactid, requestor_id, name, email, date, message, admin, attachment, attachments_removed, rating, editor]
# Index: []

# %%
ticketreplies
# Out:
#             id     tid  userid  contactid  requestor_id name email  \
# 0            1       2       0          0             0
# 1            2       2      14          0             0
# 2            3       2       0          0             0
# 3            4       3       0          0             0
# 4            5       3       6          0             0
# ...        ...     ...     ...        ...           ...  ...   ...
# 650121  650899  230177       0          0             0
# 650122  650900  230203       0          0             0
# 650123  650901  230224   93235          0         93337
# 650124  650902  230224   93235          0         93337
# 650125  650903  230224       0          0             0
#
#                       date                                            message  \
# 0      2012-06-12 04:00:18  Hello,\r\n\r\nAt the moment we only have one O...
# 1      2012-06-12 05:04:22  Do you have anything in Xen at a similar price...
# ...

# %%
tickets[tickets['tid'] == '230222']
tickets[tickets['tid'] == '230203']


tickets[tickets['tid'] == '230224']
tickets[tickets['userid'] == '93235']
# Out:
# Empty DataFrame
# Columns: [id, tid, did, userid, contactid, requestor_id, name, email, cc, c, ipaddress, date, title, message, status, urgency, admin, attachment, attachments_removed, lastreply, flag, clientunread, adminunread, replyingadmin, replyingtime, service, merged_ticket_id, editor, updated_at]
# Index: []
#
# [0 rows x 29 columns]

# %%
# Out:
#    id              name                                        description  \
# 0   1           Support  For technical support regarding your server. C...
# 1   2          Accounts  For help with accounts issues (payments, invoi...
# 2   3   Sales / General  For sales questions and general inquiries. You...
# 3   5  Abuse Department                                              Abuse
# 4   7             Legal                                              Legal
#
#                   email clientsonly piperepliesonly noautoresponder hidden  \
# 0   support@ramnode.com          on
# 1  accounts@ramnode.com          on
# 2     sales@ramnode.com
# 3     abuse@ramnode.com                                          on     on
# 4     legal@ramnode.com                                          on     on
#
#    order           host port                    login  \
# 0      1  pop.gmail.com  995      support@ramnode.com
# 1      2  pop.gmail.com  995     accounts@ramnode.com
# ...

# %%
ticketreplies.groupby('tid').count()
# Out:
#         id  userid  contactid  requestor_id  name  email  date  message  \
# tid
# 2        3       3          3             3     3      3     3        3
# 3        3       3          3             3     3      3     3        3
# 4        9       9          9             9     9      9     9        9
# 5        2       2          2             2     2      2     2        2
# 6        2       2          2             2     2      2     2        2
# ...     ..     ...        ...           ...   ...    ...   ...      ...
# 230216   3       3          3             3     3      3     3        3
# 230218   3       3          3             3     3      3     3        3
# 230222   1       1          1             1     1      1     1        1
# 230223   2       2          2             2     2      2     2        2
# 230224   4       4          4             4     4      4     4        4
#
#         admin  attachment  attachments_removed  rating  editor
# tid
# ...

# %%
ticketnotes = pd.read_sql_table('tblticketnotes', mysql_engine)
ticketnotes
# Out:
#         id  ticketid          admin                date  \
# 0        2       190     Nick Adams 2012-07-29 00:39:32
# 1        3       809     Nick Adams 2012-10-29 13:24:17
# 2        4       882     Nick Adams 2012-11-05 19:48:37
# 3        5       882     Nick Adams 2012-11-06 04:51:26
# 4        6       882     Nick Adams 2012-11-06 04:53:49
# ...    ...       ...            ...                 ...
# 5477  5694    230155  RamNode Legal 2022-09-19 12:16:40
# 5478  5695    230180  RamNode Legal 2022-09-19 13:43:22
# 5479  5696    230152  RamNode Legal 2022-09-19 13:43:44
# 5480  5697    230155  RamNode Legal 2022-09-19 13:45:35
# 5481  5698    230181  RamNode Legal 2022-09-19 13:45:42
#
#                                                 message attachments  \
# 0                          REMOVE SMTP BLOCK IF CANCELS
# 1     IPs have been removed. Still need ARIN justifi...
# 2           Rate limited to 100Mbps until we hear back.
# ...

# %%
ticketreplies
# Out:
#         id  ticketid          admin                date  \
# 0        2       190     Nick Adams 2012-07-29 00:39:32
# 1        3       809     Nick Adams 2012-10-29 13:24:17
# 2        4       882     Nick Adams 2012-11-05 19:48:37
# 3        5       882     Nick Adams 2012-11-06 04:51:26
# 4        6       882     Nick Adams 2012-11-06 04:53:49
# ...    ...       ...            ...                 ...
# 5477  5694    230155  RamNode Legal 2022-09-19 12:16:40
# 5478  5695    230180  RamNode Legal 2022-09-19 13:43:22
# 5479  5696    230152  RamNode Legal 2022-09-19 13:43:44
# 5480  5697    230155  RamNode Legal 2022-09-19 13:45:35
# 5481  5698    230181  RamNode Legal 2022-09-19 13:45:42
#
#                                                 message attachments  \
# 0                          REMOVE SMTP BLOCK IF CANCELS
# 1     IPs have been removed. Still need ARIN justifi...
# 2           Rate limited to 100Mbps until we hear back.
# ...
